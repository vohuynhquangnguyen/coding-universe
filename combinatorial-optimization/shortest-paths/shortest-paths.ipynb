# %%
from PushRelabel import PushRelabel

cap = [[0] * 7 for _ in range(7)]
    
# Source to intermediate nodes
cap[1][2] = 5
cap[1][3] = 8
cap[1][4] = 5
cap[1][5] = 3

# Intermediate connections
cap[2][4] = 4
cap[3][5] = 5
cap[4][5] = 6
cap[4][6] = 4

# Connections to sink
cap[5][6] = 12

# Run the algorithm
PushRelabel(cap, source=1, sink=6, verbose=True)
# Out:
# ------------------------------------------------------------
# Step 0 | Action: Initialize Preflow
#   Excess (Nodes 2-5): [5, 8, 5, 3]
#   Height (Nodes 1-6): [6, 0, 0, 0, 0, 0]
# ------------------------------------------------------------
# Step 1  | Node 2 | Action: Relabel (New Height: 1)
#   Excess (Nodes 2-5): [5, 8, 5, 3]
#   Height (Nodes 1-6): [6, 1, 0, 0, 0, 0]
# Step 2  | Node 2 | Action: Push (2 -> 4) by 4 units
#   Excess (Nodes 2-5): [1, 8, 9, 3]
#   Height (Nodes 1-6): [6, 1, 0, 0, 0, 0]
# Step 3  | Node 2 | Action: Relabel (New Height: 7)
#   Excess (Nodes 2-5): [1, 8, 9, 3]
#   Height (Nodes 1-6): [6, 7, 0, 0, 0, 0]
# Step 4  | Node 2 | Action: Push (2 -> 1) by 1 units
#   Excess (Nodes 2-5): [0, 8, 9, 3]
#   Height (Nodes 1-6): [6, 7, 0, 0, 0, 0]
# Step 5  | Node 3 | Action: Relabel (New Height: 1)
#   Excess (Nodes 2-5): [0, 8, 9, 3]
#   Height (Nodes 1-6): [6, 7, 1, 0, 0, 0]
# Step 6  | Node 3 | Action: Push (3 -> 5) by 5 units
# ...
