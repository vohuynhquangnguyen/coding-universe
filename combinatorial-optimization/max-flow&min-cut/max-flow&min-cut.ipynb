# %%
from edmonds_karp import EdmondsKarp

# %%
capacity = {
    1: {2: 20, 3: 13},
    2: {4:  8, 5:  6},
    3: {5: 12, 6: 14},
    4: {5: 11, 7: 21},
    5: {6:  3, 7: 10},
    6: {7:  9},
    7: {},
}
result = EdmondsKarp(capacity, source=1, sink=7).solve()
print(result.summary())
# Out:
# Edmonds-Karp Algorithm  (Ford-Fulkerson with FIFO/BFS scan)
# Source = 1, Sink = 7
#
# Original arcs (capacities):
#   (1,2)  capacity 20
#   (1,3)  capacity 13
#   (2,4)  capacity 8
#   (2,5)  capacity 6
#   (3,5)  capacity 12
#   (3,6)  capacity 14
#   (4,5)  capacity 11
#   (4,7)  capacity 21
#   (5,6)  capacity 3
#   (5,7)  capacity 10
#   (6,7)  capacity 9
#
# ========================================================================
#   ITERATION 1
# ========================================================================
#
#   [1] Initialise: label[1] = (-, ∞);  queue = [1]
#
#   [2] BFS (FIFO) scan:
#       ── pop 1  (carries δ=∞);  candidates [2, 3]
#            · 2: r(1,2)=20  → label[2]=(+1, 20);  queue=[2]
#            · 3: r(1,3)=13  → label[3]=(+1, 13);  queue=[2, 3]
#       ── pop 2  (carries δ=20);  candidates [4, 5]
#            · 4: r(2,4)=8  → label[4]=(+2, 8);  queue=[3, 4]
#            · 5: r(2,5)=6  → label[5]=(+2, 6);  queue=[3, 4, 5]
#       ── pop 3  (carries δ=13);  candidates [5, 6]
#            · 5: r(3,5)=12  but already labelled → skip
#            · 6: r(3,6)=14  → label[6]=(+3, 13);  queue=[4, 5, 6]
#       ── pop 4  (carries δ=8);  candidates [5, 7]
#            · 5: r(4,5)=11  but already labelled → skip
#            · 7: r(4,7)=21  → label[7]=(+4, 8);  queue=[5, 6, 7]
#
#   [3] Traceback from sink:
#       label[7] = (+4, 8)  →  predecessor 4
#       label[4] = (+2, 8)  →  predecessor 2
#       label[2] = (+1, 20)  →  predecessor 1
#
#       Augmenting path : 1 → 2 → 4 → 7
#       Bottleneck δ    : 8
#
#   [4] Augment by δ = 8:
#       (1,2) forward : f(1,2) ← 0 + 8 = 8
#       (2,4) forward : f(2,4) ← 0 + 8 = 8
#       (4,7) forward : f(4,7) ← 0 + 8 = 8
#
#   [5] Updated residual network:
#            Residual capacities (positive only):
#              1: (1,2,+,r=12), (1,3,+,r=13)
#              2: (2,1,-,r=8), (2,5,+,r=6)
#              3: (3,5,+,r=12), (3,6,+,r=14)
#              4: (4,2,-,r=8), (4,5,+,r=11), (4,7,+,r=13)
#              5: (5,6,+,r=3), (5,7,+,r=10)
#              6: (6,7,+,r=9)
#              7: (7,4,-,r=8)
#
#   [6] Cumulative flow after iteration 1: 8
#
# ========================================================================
#   ITERATION 2
# ========================================================================
#
#   [1] Initialise: label[1] = (-, ∞);  queue = [1]
#
#   [2] BFS (FIFO) scan:
#       ── pop 1  (carries δ=∞);  candidates [2, 3]
#            · 2: r(1,2)=12  → label[2]=(+1, 12);  queue=[2]
#            · 3: r(1,3)=13  → label[3]=(+1, 13);  queue=[2, 3]
#       ── pop 2  (carries δ=12);  candidates [1, 4, 5]
#            · 1: r(2,1)=8  but already labelled → skip
#            · 4: r(2,4)=0  → skip
#            · 5: r(2,5)=6  → label[5]=(+2, 6);  queue=[3, 5]
#       ── pop 3  (carries δ=13);  candidates [5, 6]
#            · 5: r(3,5)=12  but already labelled → skip
#            · 6: r(3,6)=14  → label[6]=(+3, 13);  queue=[5, 6]
#       ── pop 5  (carries δ=6);  candidates [6, 7]
#            · 6: r(5,6)=3  but already labelled → skip
#            · 7: r(5,7)=10  → label[7]=(+5, 6);  queue=[6, 7]
#
#   [3] Traceback from sink:
#       label[7] = (+5, 6)  →  predecessor 5
#       label[5] = (+2, 6)  →  predecessor 2
#       label[2] = (+1, 12)  →  predecessor 1
#
#       Augmenting path : 1 → 2 → 5 → 7
#       Bottleneck δ    : 6
#
#   [4] Augment by δ = 6:
#       (1,2) forward : f(1,2) ← 8 + 6 = 14
#       (2,5) forward : f(2,5) ← 0 + 6 = 6
#       (5,7) forward : f(5,7) ← 0 + 6 = 6
#
#   [5] Updated residual network:
#            Residual capacities (positive only):
#              1: (1,2,+,r=6), (1,3,+,r=13)
#              2: (2,1,-,r=14)
#              3: (3,5,+,r=12), (3,6,+,r=14)
#              4: (4,2,-,r=8), (4,5,+,r=11), (4,7,+,r=13)
#              5: (5,2,-,r=6), (5,6,+,r=3), (5,7,+,r=4)
#              6: (6,7,+,r=9)
#              7: (7,4,-,r=8), (7,5,-,r=6)
#
#   [6] Cumulative flow after iteration 2: 14
#
# ========================================================================
#   ITERATION 3
# ========================================================================
#
#   [1] Initialise: label[1] = (-, ∞);  queue = [1]
#
#   [2] BFS (FIFO) scan:
#       ── pop 1  (carries δ=∞);  candidates [2, 3]
#            · 2: r(1,2)=6  → label[2]=(+1, 6);  queue=[2]
#            · 3: r(1,3)=13  → label[3]=(+1, 13);  queue=[2, 3]
#       ── pop 2  (carries δ=6);  candidates [1, 4, 5]
#            · 1: r(2,1)=14  but already labelled → skip
#            · 4: r(2,4)=0  → skip
#            · 5: r(2,5)=0  → skip
#       ── pop 3  (carries δ=13);  candidates [5, 6]
#            · 5: r(3,5)=12  → label[5]=(+3, 12);  queue=[5]
#            · 6: r(3,6)=14  → label[6]=(+3, 13);  queue=[5, 6]
#       ── pop 5  (carries δ=12);  candidates [2, 6, 7]
#            · 2: r(5,2)=6  but already labelled → skip
#            · 6: r(5,6)=3  but already labelled → skip
#            · 7: r(5,7)=4  → label[7]=(+5, 4);  queue=[6, 7]
#
#   [3] Traceback from sink:
#       label[7] = (+5, 4)  →  predecessor 5
#       label[5] = (+3, 12)  →  predecessor 3
#       label[3] = (+1, 13)  →  predecessor 1
#
#       Augmenting path : 1 → 3 → 5 → 7
#       Bottleneck δ    : 4
#
#   [4] Augment by δ = 4:
#       (1,3) forward : f(1,3) ← 0 + 4 = 4
#       (3,5) forward : f(3,5) ← 0 + 4 = 4
#       (5,7) forward : f(5,7) ← 6 + 4 = 10
#
#   [5] Updated residual network:
#            Residual capacities (positive only):
#              1: (1,2,+,r=6), (1,3,+,r=9)
#              2: (2,1,-,r=14)
#              3: (3,1,-,r=4), (3,5,+,r=8), (3,6,+,r=14)
#              4: (4,2,-,r=8), (4,5,+,r=11), (4,7,+,r=13)
#              5: (5,2,-,r=6), (5,3,-,r=4), (5,6,+,r=3)
#              6: (6,7,+,r=9)
#              7: (7,4,-,r=8), (7,5,-,r=10)
#
#   [6] Cumulative flow after iteration 3: 18
#
# ========================================================================
#   ITERATION 4
# ========================================================================
#
#   [1] Initialise: label[1] = (-, ∞);  queue = [1]
#
#   [2] BFS (FIFO) scan:
#       ── pop 1  (carries δ=∞);  candidates [2, 3]
#            · 2: r(1,2)=6  → label[2]=(+1, 6);  queue=[2]
#            · 3: r(1,3)=9  → label[3]=(+1, 9);  queue=[2, 3]
#       ── pop 2  (carries δ=6);  candidates [1, 4, 5]
#            · 1: r(2,1)=14  but already labelled → skip
#            · 4: r(2,4)=0  → skip
#            · 5: r(2,5)=0  → skip
#       ── pop 3  (carries δ=9);  candidates [1, 5, 6]
#            · 1: r(3,1)=4  but already labelled → skip
#            · 5: r(3,5)=8  → label[5]=(+3, 8);  queue=[5]
#            · 6: r(3,6)=14  → label[6]=(+3, 9);  queue=[5, 6]
#       ── pop 5  (carries δ=8);  candidates [2, 3, 6, 7]
#            · 2: r(5,2)=6  but already labelled → skip
#            · 3: r(5,3)=4  but already labelled → skip
#            · 6: r(5,6)=3  but already labelled → skip
#            · 7: r(5,7)=0  → skip
#       ── pop 6  (carries δ=9);  candidates [7]
#            · 7: r(6,7)=9  → label[7]=(+6, 9);  queue=[7]
#
#   [3] Traceback from sink:
#       label[7] = (+6, 9)  →  predecessor 6
#       label[6] = (+3, 9)  →  predecessor 3
#       label[3] = (+1, 9)  →  predecessor 1
#
#       Augmenting path : 1 → 3 → 6 → 7
#       Bottleneck δ    : 9
#
#   [4] Augment by δ = 9:
#       (1,3) forward : f(1,3) ← 4 + 9 = 13
#       (3,6) forward : f(3,6) ← 0 + 9 = 9
#       (6,7) forward : f(6,7) ← 0 + 9 = 9
#
#   [5] Updated residual network:
#            Residual capacities (positive only):
#              1: (1,2,+,r=6)
#              2: (2,1,-,r=14)
#              3: (3,1,-,r=13), (3,5,+,r=8), (3,6,+,r=5)
#              4: (4,2,-,r=8), (4,5,+,r=11), (4,7,+,r=13)
#              5: (5,2,-,r=6), (5,3,-,r=4), (5,6,+,r=3)
#              6: (6,3,-,r=9)
#              7: (7,4,-,r=8), (7,5,-,r=10), (7,6,-,r=9)
#
#   [6] Cumulative flow after iteration 4: 27
#
# ========================================================================
#   ITERATION 5
# ========================================================================
#
#   [1] Initialise: label[1] = (-, ∞);  queue = [1]
#
#   [2] BFS (FIFO) scan:
#       ── pop 1  (carries δ=∞);  candidates [2, 3]
#            · 2: r(1,2)=6  → label[2]=(+1, 6);  queue=[2]
#            · 3: r(1,3)=0  → skip
#       ── pop 2  (carries δ=6);  candidates [1, 4, 5]
#            · 1: r(2,1)=14  but already labelled → skip
#            · 4: r(2,4)=0  → skip
#            · 5: r(2,5)=0  → skip
#
#       Queue exhausted; sink 7 not labelled.
#       ALGORITHM TERMINATES.
#
# ════════════════════════════════════════════════════════════════
#   Max-Flow / Min-Cut Result  (Edmonds-Karp)
# ════════════════════════════════════════════════════════════════
#   Max flow value         : 27
#   Min cut capacity       : 27    ✓  matches max flow
#   Source-side  S         : [1, 2]
#   Sink-side    T         : [3, 4, 5, 6, 7]
#   Iterations (incl. last): 5
#   Cut arcs (S → T):
#     (1,3)  capacity 13
#     (2,4)  capacity 8
#     (2,5)  capacity 6
#   Final non-zero flows:
#     f(1,2) = 14
#     f(1,3) = 13
#     f(2,4) = 8
#     f(2,5) = 6
#     f(3,5) = 4
#     f(3,6) = 9
#     f(4,7) = 8
#     f(5,7) = 10
#     f(6,7) = 9
# ════════════════════════════════════════════════════════════════
#   Max-Flow / Min-Cut Result  (Edmonds-Karp)
# ════════════════════════════════════════════════════════════════
#   Max flow value         : 27
#   Min cut capacity       : 27    ✓  matches max flow
#   Source-side  S         : [1, 2]
#   Sink-side    T         : [3, 4, 5, 6, 7]
#   Iterations (incl. last): 5
#   Cut arcs (S → T):
#     (1,3)  capacity 13
#     (2,4)  capacity 8
#     (2,5)  capacity 6
#   Final non-zero flows:
#     f(1,2) = 14
#     f(1,3) = 13
#     f(2,4) = 8
#     f(2,5) = 6
#     f(3,5) = 4
#     f(3,6) = 9
#     f(4,7) = 8
#     f(5,7) = 10
#     f(6,7) = 9
